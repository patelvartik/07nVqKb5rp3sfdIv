# %% [markdown]
# # Potential Talents

# %% [markdown]
# ## 1. Explorative Data Analysis

# %% [markdown]
# ### 1.1. Data Import

# %%
import pandas as pd

data = pd.read_csv('potential-talents.csv')

# %% [markdown]
# ### 1.2. Data Description

# %%
corpus=""
for temp in data['job_title']:
    corpus=corpus+ " " +temp

# %%
import nltk

tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')

tokens = tokenizer.tokenize(corpus)

# %%
freq = nltk.FreqDist(tokens)
freq
# Out:
# FreqDist({'Human': 63, 'Resources': 63, 'at': 46, 'and': 28, 'Aspiring': 27, 'College': 14, 'Student': 14, 'Generalist': 14, 'Professional': 12, 'University': 12, ...})

# %% [markdown]
# The most frequent words in the dataset are Human and Resources.

# %% [markdown]
# ## 2. Candidate  Ranking

# %% [markdown]
# ### 2.1. Ranking using Tokenize

# %% [markdown]
# In this section ranking of candidates is based on similarity with the target job title i.e. "Aspiring human resources" has been carried out.
# To achieve this, the sentence has been transformed into a group of words without stopwords. Using the cosine similarity method similarity between two sentences has been measured.

# %%
X="Aspiring human resources"
X_token=tokenizer.tokenize(X.lower())

results = []
for row in range(len(data)):
    tokens = tokenizer.tokenize((data['job_title'][row].lower()))
    
    # sw contains the list of stopwords
    sw = nltk.corpus.stopwords.words('english') 
    l1 =[];l2 =[]

    # remove stop words from the string
    X_set = {w for w in X_token if not w in sw} 
    Y_set = {w for w in tokens if not w in sw}

    # form a set containing keywords of both strings 
    rvector = X_set.union(Y_set) 
    for w in rvector:
        if w in X_set: l1.append(1) # create a vector
        else: l1.append(0)
        if w in Y_set: l2.append(1)
        else: l2.append(0)
    c = 0

    # cosine formula 
    for i in range(len(rvector)):
            c+= l1[i]*l2[i]
    cosine = c / float((sum(l1)*sum(l2))**0.5)

    results.append({"id":  data['id'][row],"job_title": data['job_title'][row], "score": cosine})

    
results.sort(key=lambda k: k["score"], reverse=True)
results
# Out:
# [{'id': 3,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 6,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'score': 0.8660254037844387},
#  {'id': 17,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 21,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 24,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'score': 0.8660254037844387},
#  {'id': 33,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 36,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'score': 0.8660254037844387},
#  {'id': 46,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 49,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'score': 0.8660254037844387},
#  {'id': 58,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 60,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'score': 0.8660254037844387},
#  {'id': 97,
#   'job_title': 'Aspiring Human Resources Professional',
#   'score': 0.8660254037844387},
#  {'id': 73,
#   'job_title': 'Aspiring Human Resources Manager, seeking internship in Human Resources.',
#   'score': 0.7071067811865476},
#  {'id': 74,
#   'job_title': 'Human Resources Professional',
#   'score': 0.6666666666666666},
#  {'id': 7,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 9,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 25,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 27,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'score': 0.6546536707079772},
#  {'id': 29,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'score': 0.6546536707079772},
#  {'id': 37,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 39,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 50,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 52,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'score': 0.6546536707079772},
#  {'id': 66,
#   'job_title': 'Experienced Retail Manager and aspiring Human Resources Professional',
#   'score': 0.6546536707079772},
#  {'id': 72,
#   'job_title': 'Business Management Major and Aspiring Human Resources Manager',
#   'score': 0.6546536707079772},
#  {'id': 79,
#   'job_title': 'Liberal Arts Major. Aspiring Human Resources Analyst.',
#   'score': 0.6546536707079772},
#  {'id': 82,
#   'job_title': 'Aspiring Human Resources Professional | An energetic and Team-Focused Leader',
#   'score': 0.6123724356957946},
#  {'id': 28,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'score': 0.5773502691896258},
#  {'id': 30,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'score': 0.5773502691896258},
#  {'id': 68,
#   'job_title': 'Human Resources Specialist at Luxottica',
#   'score': 0.5773502691896258},
#  {'id': 78,
#   'job_title': "Human Resources Generalist at Schwan's",
#   'score': 0.5773502691896258},
#  {'id': 88,
#   'job_title': 'Human Resources Management Major',
#   'score': 0.5773502691896258},
#  {'id': 89,
#   'job_title': 'Director Human Resources  at EY',
#   'score': 0.5773502691896258},
#  {'id': 99,
#   'job_title': 'Seeking Human Resources Position',
#   'score': 0.5773502691896258},
#  {'id': 101,
#   'job_title': 'Human Resources Generalist at Loparex',
#   'score': 0.5773502691896258},
#  {'id': 76,
#   'job_title': 'Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment',
#   'score': 0.5222329678670935},
#  {'id': 67,
#   'job_title': 'Human Resources, Staffing and Recruiting Professional',
#   'score': 0.5163977794943222},
#  {'id': 71,
#   'job_title': 'Human Resources Generalist at ScottMadden, Inc.',
#   'score': 0.5163977794943222},
#  {'id': 1,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 14,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 15,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 19,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 31,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 44,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 57,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'score': 0.48038446141526137},
#  {'id': 100,
#   'job_title': 'Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis',
#   'score': 0.48038446141526137},
#  {'id': 10,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'score': 0.47140452079103173},
#  {'id': 13,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'score': 0.47140452079103173},
#  {'id': 40,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'score': 0.47140452079103173},
#  {'id': 43,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'score': 0.47140452079103173},
#  {'id': 53,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'score': 0.47140452079103173},
#  {'id': 56,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'score': 0.47140452079103173},
#  {'id': 62,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'score': 0.47140452079103173},
#  {'id': 65,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'score': 0.47140452079103173},
#  {'id': 69,
#   'job_title': 'Director of Human Resources North America, Groupe Beneteau',
#   'score': 0.4364357804719848},
#  {'id': 81,
#   'job_title': 'Senior Human Resources Business Partner at Heil Environmental',
#   'score': 0.4364357804719848},
#  {'id': 84,
#   'job_title': 'Human Resources professional for the world leader in GIS software',
#   'score': 0.4364357804719848},
#  {'id': 94,
#   'job_title': 'Seeking Human  Resources Opportunities. Open to travel and relocation.',
#   'score': 0.4364357804719848},
#  {'id': 77,
#   'job_title': 'Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation',
#   'score': 0.3849001794597505},
#  {'id': 70,
#   'job_title': 'Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.',
#   'score': 0.3481553119113957},
#  {'id': 75,
#   'job_title': 'Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621',
#   'score': 0.3481553119113957},
#  {'id': 2,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'score': 0.0},
#  {'id': 4,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 5,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'score': 0.0},
#  {'id': 8, 'job_title': 'HR Senior Specialist', 'score': 0.0},
#  {'id': 11, 'job_title': 'Student at Chapman University', 'score': 0.0},
#  {'id': 12,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'score': 0.0},
#  {'id': 16,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'score': 0.0},
#  {'id': 18,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 20,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'score': 0.0},
#  {'id': 22,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 23,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'score': 0.0},
#  {'id': 26, 'job_title': 'HR Senior Specialist', 'score': 0.0},
#  {'id': 32,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'score': 0.0},
#  {'id': 34,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 35,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'score': 0.0},
#  {'id': 38, 'job_title': 'HR Senior Specialist', 'score': 0.0},
#  {'id': 41, 'job_title': 'Student at Chapman University', 'score': 0.0},
#  {'id': 42,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'score': 0.0},
#  {'id': 45,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'score': 0.0},
#  {'id': 47,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 48,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'score': 0.0},
#  {'id': 51, 'job_title': 'HR Senior Specialist', 'score': 0.0},
#  {'id': 54, 'job_title': 'Student at Chapman University', 'score': 0.0},
#  {'id': 55,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'score': 0.0},
#  {'id': 59,
#   'job_title': 'People Development Coordinator at Ryan',
#   'score': 0.0},
#  {'id': 61, 'job_title': 'HR Senior Specialist', 'score': 0.0},
#  {'id': 63, 'job_title': 'Student at Chapman University', 'score': 0.0},
#  {'id': 64,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'score': 0.0},
#  {'id': 80,
#   'job_title': 'Junior MES Engineer| Information Systems',
#   'score': 0.0},
#  {'id': 83,
#   'job_title': 'HR Manager at Endemol Shine North America',
#   'score': 0.0},
#  {'id': 85,
#   'job_title': 'RRP Brand Portfolio Executive at JTI (Japan Tobacco International)',
#   'score': 0.0},
#  {'id': 86,
#   'job_title': 'Information Systems Specialist and Programmer with a love for data and organization.',
#   'score': 0.0},
#  {'id': 87,
#   'job_title': 'Bachelor of Science in Biology from Victoria University of Wellington',
#   'score': 0.0},
#  {'id': 90,
#   'job_title': 'Undergraduate Research Assistant at Styczynski Lab',
#   'score': 0.0},
#  {'id': 91,
#   'job_title': 'Lead Official at Western Illinois University',
#   'score': 0.0},
#  {'id': 92,
#   'job_title': 'Seeking employment opportunities within Customer Service or Patient Care',
#   'score': 0.0},
#  {'id': 93,
#   'job_title': 'Admissions Representative at Community medical center long beach',
#   'score': 0.0},
#  {'id': 95,
#   'job_title': 'Student at Westfield State University',
#   'score': 0.0},
#  {'id': 96,
#   'job_title': 'Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint',
#   'score': 0.0},
#  {'id': 98, 'job_title': 'Student', 'score': 0.0},
#  {'id': 102,
#   'job_title': 'Business Intelligence and Analytics at Travelers',
#   'score': 0.0},
#  {'id': 103, 'job_title': 'Always set them up for Success', 'score': 0.0},
#  {'id': 104,
#   'job_title': 'Director Of Administration at Excellence Logging',
#   'score': 0.0}]

# %% [markdown]
# From the results, we can see a candidate whose job title contains words from "Aspiring human resources" has been ranked higher.

# %% [markdown]
# ### 2.2. Ranking using Vectorization

# %% [markdown]
# This section shows the implementation of candidates' ranking by transforming job titles as the average vector of words. The similarity of the candidate location with the targeted location has been calculated. The final similarity is the weighted average of both similarities.
#
# Xt = 0.9Xa + 0.1Xb
# Where,
# Xa = similarity score of job title
# Xb = similarity score of a location
# Xt = resultant similarity

# %%
import numpy as np


class DocSim:
    def __init__(self, w2v_model, stopwords=None):
        self.w2v_model = w2v_model
        self.stopwords = stopwords if stopwords is not None else []

    def vectorize(self, doc: str) -> np.ndarray:
        """
        Identify the vector values for each word in the given document
        :param doc:
        :return:
        """
        doc = doc.lower()
        words = [w for w in doc.split(" ") if w not in self.stopwords]
        word_vecs = []
        for word in words:
            try:
                vec = self.w2v_model[word]
                word_vecs.append(vec)
            except KeyError:
                # Ignore, if the word doesn't exist in the vocabulary
                pass

        # Assuming that document vector is the mean of all the word vectors
        # PS: There are other & better ways to do it.
        vector = np.mean(word_vecs, axis=0)
        return vector

    def _cosine_sim(self, vecA, vecB):
        """Find the cosine similarity distance between two vectors."""
        csim = np.dot(vecA, vecB) / (np.linalg.norm(vecA) * np.linalg.norm(vecB))
        if np.isnan(np.sum(csim)):
            return 0
        return csim

# %%
from gensim.models.keyedvectors import KeyedVectors

# Using the pre-trained word2vec model trained using Google news corpus of 3 billion running words.
# The model can be downloaded here: https://bit.ly/w2vgdrive (~1.4GB)
# Feel free to use to your own model.
googlenews_model_path = './pt_data/GoogleNews-vectors-negative300.bin.gz'
stopwords_path = "./pt_data/stopwords_en.txt"

model = KeyedVectors.load_word2vec_format(googlenews_model_path, binary=True)
with open(stopwords_path, 'r') as fh:
    stopwords = fh.read().split(",")
ds = DocSim(model,stopwords=stopwords)

# %%
ideal_job = "Aspiring human resources"
ideal_loc = "New York"

results = []
for row in range(len(data)):
    cand_job = str(data['job_title'][row])
    cand_loc = str(data['location'][row])
    
    job_source_vec = ds.vectorize(ideal_job)
    job_target_vec = ds.vectorize(cand_job)
    job_sim_score = ds._cosine_sim(job_source_vec, job_target_vec)
    
    loc_source_vec = ds.vectorize(ideal_loc)
    loc_target_vec = ds.vectorize(cand_loc)
    loc_sim_score = ds._cosine_sim(loc_source_vec, loc_target_vec)
    
    sim_score=0.9*job_sim_score+0.1*loc_sim_score
    
    results.append({"id":  data['id'][row],"job_title": data['job_title'][row], "location": data['location'][row], "score": sim_score})


    results.sort(key=lambda k: k["score"], reverse=True)
results
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\patel\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [{'id': 6,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.9030113697052002},
#  {'id': 24,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.9030113697052002},
#  {'id': 36,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.9030113697052002},
#  {'id': 49,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.9030113697052002},
#  {'id': 60,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.9030113697052002},
#  {'id': 97,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Kokomo, Indiana Area',
#   'score': 0.8979275226593019},
#  {'id': 3,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 17,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 21,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 33,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 46,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 58,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.8797976911067963},
#  {'id': 73,
#   'job_title': 'Aspiring Human Resources Manager, seeking internship in Human Resources.',
#   'location': 'Houston, Texas Area',
#   'score': 0.8362302958965301},
#  {'id': 74,
#   'job_title': 'Human Resources Professional',
#   'location': 'Greater Boston Area',
#   'score': 0.8320525527000427},
#  {'id': 100,
#   'job_title': 'Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis',
#   'location': 'Cape Girardeau, Missouri',
#   'score': 0.7844448804855346},
#  {'id': 82,
#   'job_title': 'Aspiring Human Resources Professional | An energetic and Team-Focused Leader',
#   'location': 'Austin, Texas Area',
#   'score': 0.7843924760818481},
#  {'id': 79,
#   'job_title': 'Liberal Arts Major. Aspiring Human Resources Analyst.',
#   'location': 'Baton Rouge, Louisiana Area',
#   'score': 0.7560438364744188},
#  {'id': 76,
#   'job_title': 'Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment',
#   'location': 'New York, New York',
#   'score': 0.7506276905536652},
#  {'id': 27,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'location': 'Houston, Texas Area',
#   'score': 0.7435626566410064},
#  {'id': 29,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'location': 'Houston, Texas Area',
#   'score': 0.7435626566410064},
#  {'id': 68,
#   'job_title': 'Human Resources Specialist at Luxottica',
#   'location': 'Greater New York City Area',
#   'score': 0.7425425827503205},
#  {'id': 66,
#   'job_title': 'Experienced Retail Manager and aspiring Human Resources Professional',
#   'location': 'Austin, Texas Area',
#   'score': 0.7344166457653045},
#  {'id': 7,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 9,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 25,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 37,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 39,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 50,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 52,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.7338343620300293},
#  {'id': 1,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 14,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 15,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 19,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 31,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 44,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 57,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.7263696432113648},
#  {'id': 101,
#   'job_title': 'Human Resources Generalist at Loparex',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.7240033507347107},
#  {'id': 72,
#   'job_title': 'Business Management Major and Aspiring Human Resources Manager',
#   'location': 'Monroe, Louisiana Area',
#   'score': 0.7211876094341279},
#  {'id': 28,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'location': 'Chicago, Illinois',
#   'score': 0.713985225558281},
#  {'id': 30,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'location': 'Chicago, Illinois',
#   'score': 0.713985225558281},
#  {'id': 88,
#   'job_title': 'Human Resources Management Major',
#   'location': 'Milpitas, California',
#   'score': 0.6964565604925156},
#  {'id': 99,
#   'job_title': 'Seeking Human Resources Position',
#   'location': 'Las Vegas, Nevada Area',
#   'score': 0.69634208381176},
#  {'id': 78,
#   'job_title': "Human Resources Generalist at Schwan's",
#   'location': 'Amerika Birleşik Devletleri',
#   'score': 0.6947230339050293},
#  {'id': 10,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6782063305377961},
#  {'id': 40,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6782063305377961},
#  {'id': 53,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6782063305377961},
#  {'id': 62,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6782063305377961},
#  {'id': 84,
#   'job_title': 'Human Resources professional for the world leader in GIS software',
#   'location': 'Highland, California',
#   'score': 0.6607338815927506},
#  {'id': 71,
#   'job_title': 'Human Resources Generalist at ScottMadden, Inc.',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.6420615434646606},
#  {'id': 94,
#   'job_title': 'Seeking Human  Resources Opportunities. Open to travel and relocation.',
#   'location': 'Amerika Birleşik Devletleri',
#   'score': 0.6419535219669342},
#  {'id': 81,
#   'job_title': 'Senior Human Resources Business Partner at Heil Environmental',
#   'location': 'Chattanooga, Tennessee Area',
#   'score': 0.6286201864480973},
#  {'id': 89,
#   'job_title': 'Director Human Resources  at EY',
#   'location': 'Greater Atlanta Area',
#   'score': 0.6008931756019592},
#  {'id': 69,
#   'job_title': 'Director of Human Resources North America, Groupe Beneteau',
#   'location': 'Greater Grand Rapids, Michigan Area',
#   'score': 0.5891697108745576},
#  {'id': 67,
#   'job_title': 'Human Resources, Staffing and Recruiting Professional',
#   'location': 'Jackson, Mississippi Area',
#   'score': 0.5742141366004944},
#  {'id': 13,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5691489189863206},
#  {'id': 43,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5691489189863206},
#  {'id': 56,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5691489189863206},
#  {'id': 65,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5691489189863206},
#  {'id': 75,
#   'job_title': 'Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621',
#   'location': 'San Jose, California',
#   'score': 0.4750676333904267},
#  {'id': 70,
#   'job_title': 'Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.',
#   'location': 'Virginia Beach, Virginia',
#   'score': 0.421245875954628},
#  {'id': 86,
#   'job_title': 'Information Systems Specialist and Programmer with a love for data and organization.',
#   'location': 'Gaithersburg, Maryland',
#   'score': 0.3615066647529602},
#  {'id': 90,
#   'job_title': 'Undergraduate Research Assistant at Styczynski Lab',
#   'location': 'Greater Atlanta Area',
#   'score': 0.3535985469818116},
#  {'id': 92,
#   'job_title': 'Seeking employment opportunities within Customer Service or Patient Care',
#   'location': 'Torrance, California',
#   'score': 0.3494879066944122},
#  {'id': 96,
#   'job_title': 'Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint',
#   'location': 'Lafayette, Indiana',
#   'score': 0.34806845188140867},
#  {'id': 102,
#   'job_title': 'Business Intelligence and Analytics at Travelers',
#   'location': 'Greater New York City Area',
#   'score': 0.3444528758525849},
#  {'id': 77,
#   'job_title': 'Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation',
#   'location': 'Dallas/Fort Worth Area',
#   'score': 0.33904764503240586},
#  {'id': 12,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.32361578941345215},
#  {'id': 42,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.32361578941345215},
#  {'id': 55,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.32361578941345215},
#  {'id': 64,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.32361578941345215},
#  {'id': 80,
#   'job_title': 'Junior MES Engineer| Information Systems',
#   'location': 'Myrtle Beach, South Carolina Area',
#   'score': 0.3140884280204773},
#  {'id': 4,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 18,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 22,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 34,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 47,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 59,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.3047898203134537},
#  {'id': 87,
#   'job_title': 'Bachelor of Science in Biology from Victoria University of Wellington',
#   'location': 'Baltimore, Maryland',
#   'score': 0.2936920791864395},
#  {'id': 93,
#   'job_title': 'Admissions Representative at Community medical center long beach',
#   'location': 'Long Beach, California',
#   'score': 0.293312069773674},
#  {'id': 91,
#   'job_title': 'Lead Official at Western Illinois University',
#   'location': 'Greater Chicago Area',
#   'score': 0.2844923436641693},
#  {'id': 95,
#   'job_title': 'Student at Westfield State University',
#   'location': 'Bridgewater, Massachusetts',
#   'score': 0.26210904866456985},
#  {'id': 104,
#   'job_title': 'Director Of Administration at Excellence Logging',
#   'location': 'Katy, Texas',
#   'score': 0.26194992661476135},
#  {'id': 11,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.24952609091997147},
#  {'id': 41,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.24952609091997147},
#  {'id': 54,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.24952609091997147},
#  {'id': 63,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.24952609091997147},
#  {'id': 98,
#   'job_title': 'Student',
#   'location': 'Houston, Texas Area',
#   'score': 0.2458632975816727},
#  {'id': 2,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.23890376687049866},
#  {'id': 16,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.23890376687049866},
#  {'id': 20,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.23890376687049866},
#  {'id': 32,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.23890376687049866},
#  {'id': 45,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.23890376687049866},
#  {'id': 83,
#   'job_title': 'HR Manager at Endemol Shine North America',
#   'location': 'Los Angeles, California',
#   'score': 0.2035778358578682},
#  {'id': 5,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.19464227557182312},
#  {'id': 23,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.19464227557182312},
#  {'id': 35,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.19464227557182312},
#  {'id': 48,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.19464227557182312},
#  {'id': 85,
#   'job_title': 'RRP Brand Portfolio Executive at JTI (Japan Tobacco International)',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.17507858276367189},
#  {'id': 8,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.17475439161062242},
#  {'id': 26,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.17475439161062242},
#  {'id': 38,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.17475439161062242},
#  {'id': 51,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.17475439161062242},
#  {'id': 61,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.17475439161062242},
#  {'id': 103,
#   'job_title': 'Always set them up for Success',
#   'location': 'Greater Los Angeles Area',
#   'score': 0.17081993371248247}]

# %% [markdown]
# It can be seen that candidate that has similar words to the target job title has been ranked higher. Among similar job titles candidates, a candidate with a more similar location to the target location is ranked higher.

# %% [markdown]
# ## 3. Similarity Reranking

# %% [markdown]
# If the candidate is starred then the job title of that candidate can be considered the target job title and the location of that candidate is considered the target location. Based on this job title and location similarity of all candidates can be recalculated and reranked.

# %%
stared_id = int(input("Enter id of stared candidate: "))
# Out:
# Enter id of stared candidate: 3

# %%
ideal_job = data['job_title'][stared_id-1]
ideal_loc = data['location'][stared_id-1]

results = []
for row in range(len(data)):
    cand_job = str(data['job_title'][row])
    cand_loc = str(data['location'][row])
    
    job_source_vec = ds.vectorize(ideal_job)
    job_target_vec = ds.vectorize(cand_job)
    job_sim_score = ds._cosine_sim(job_source_vec, job_target_vec)
    
    loc_source_vec = ds.vectorize(ideal_loc)
    loc_target_vec = ds.vectorize(cand_loc)
    loc_sim_score = ds._cosine_sim(loc_source_vec, loc_target_vec)
    
    sim_score=0.9*job_sim_score+0.1*loc_sim_score
    results.append({"id":  data['id'][row],"job_title": data['job_title'][row], "location": data['location'][row], "score": sim_score})


    results.sort(key=lambda k: k["score"], reverse=True)
results
# Out:
# [{'id': 3,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 17,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 21,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 33,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 46,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 58,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 1.0000000953674317},
#  {'id': 97,
#   'job_title': 'Aspiring Human Resources Professional',
#   'location': 'Kokomo, Indiana Area',
#   'score': 0.9466425329446794},
#  {'id': 74,
#   'job_title': 'Human Resources Professional',
#   'location': 'Greater Boston Area',
#   'score': 0.8507705658674241},
#  {'id': 82,
#   'job_title': 'Aspiring Human Resources Professional | An energetic and Team-Focused Leader',
#   'location': 'Austin, Texas Area',
#   'score': 0.8423459082841874},
#  {'id': 6,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.8294936269521713},
#  {'id': 24,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.8294936269521713},
#  {'id': 36,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.8294936269521713},
#  {'id': 49,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.8294936269521713},
#  {'id': 60,
#   'job_title': 'Aspiring Human Resources Specialist',
#   'location': 'Greater New York City Area',
#   'score': 0.8294936269521713},
#  {'id': 73,
#   'job_title': 'Aspiring Human Resources Manager, seeking internship in Human Resources.',
#   'location': 'Houston, Texas Area',
#   'score': 0.8084248155355455},
#  {'id': 1,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 14,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 15,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 19,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 31,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 44,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 57,
#   'job_title': '2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional',
#   'location': 'Houston, Texas',
#   'score': 0.8070138663053513},
#  {'id': 66,
#   'job_title': 'Experienced Retail Manager and aspiring Human Resources Professional',
#   'location': 'Austin, Texas Area',
#   'score': 0.8043870180845262},
#  {'id': 100,
#   'job_title': 'Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis',
#   'location': 'Cape Girardeau, Missouri',
#   'score': 0.7670830130577088},
#  {'id': 101,
#   'job_title': 'Human Resources Generalist at Loparex',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.7506685972213746},
#  {'id': 27,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'location': 'Houston, Texas Area',
#   'score': 0.7456364482641221},
#  {'id': 29,
#   'job_title': 'Aspiring Human Resources Management student seeking an internship',
#   'location': 'Houston, Texas Area',
#   'score': 0.7456364482641221},
#  {'id': 7,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 9,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 25,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 37,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 39,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 50,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 52,
#   'job_title': 'Student at Humber College and Aspiring Human Resources Generalist',
#   'location': 'Kanada',
#   'score': 0.744551932811737},
#  {'id': 72,
#   'job_title': 'Business Management Major and Aspiring Human Resources Manager',
#   'location': 'Monroe, Louisiana Area',
#   'score': 0.7376289248466492},
#  {'id': 76,
#   'job_title': 'Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment',
#   'location': 'New York, New York',
#   'score': 0.7235291361808777},
#  {'id': 79,
#   'job_title': 'Liberal Arts Major. Aspiring Human Resources Analyst.',
#   'location': 'Baton Rouge, Louisiana Area',
#   'score': 0.7232998177409172},
#  {'id': 84,
#   'job_title': 'Human Resources professional for the world leader in GIS software',
#   'location': 'Highland, California',
#   'score': 0.699511468410492},
#  {'id': 71,
#   'job_title': 'Human Resources Generalist at ScottMadden, Inc.',
#   'location': 'Raleigh-Durham, North Carolina Area',
#   'score': 0.6788897871971131},
#  {'id': 28,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'location': 'Chicago, Illinois',
#   'score': 0.6596523016691208},
#  {'id': 30,
#   'job_title': 'Seeking Human Resources Opportunities',
#   'location': 'Chicago, Illinois',
#   'score': 0.6596523016691208},
#  {'id': 67,
#   'job_title': 'Human Resources, Staffing and Recruiting Professional',
#   'location': 'Jackson, Mississippi Area',
#   'score': 0.656229680776596},
#  {'id': 78,
#   'job_title': "Human Resources Generalist at Schwan's",
#   'location': 'Amerika Birleşik Devletleri',
#   'score': 0.6506686091423035},
#  {'id': 88,
#   'job_title': 'Human Resources Management Major',
#   'location': 'Milpitas, California',
#   'score': 0.6461352407932283},
#  {'id': 10,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6410579115152358},
#  {'id': 40,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6410579115152358},
#  {'id': 53,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6410579115152358},
#  {'id': 62,
#   'job_title': 'Seeking Human Resources HRIS and Generalist Positions',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.6410579115152358},
#  {'id': 68,
#   'job_title': 'Human Resources Specialist at Luxottica',
#   'location': 'Greater New York City Area',
#   'score': 0.6401797741651536},
#  {'id': 99,
#   'job_title': 'Seeking Human Resources Position',
#   'location': 'Las Vegas, Nevada Area',
#   'score': 0.6232389360666276},
#  {'id': 81,
#   'job_title': 'Senior Human Resources Business Partner at Heil Environmental',
#   'location': 'Chattanooga, Tennessee Area',
#   'score': 0.6056345105171205},
#  {'id': 94,
#   'job_title': 'Seeking Human  Resources Opportunities. Open to travel and relocation.',
#   'location': 'Amerika Birleşik Devletleri',
#   'score': 0.5818097591400146},
#  {'id': 13,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5378180384635926},
#  {'id': 43,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5378180384635926},
#  {'id': 56,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5378180384635926},
#  {'id': 65,
#   'job_title': 'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#   'location': 'Atlanta, Georgia',
#   'score': 0.5378180384635926},
#  {'id': 89,
#   'job_title': 'Director Human Resources  at EY',
#   'location': 'Greater Atlanta Area',
#   'score': 0.5334806233644486},
#  {'id': 69,
#   'job_title': 'Director of Human Resources North America, Groupe Beneteau',
#   'location': 'Greater Grand Rapids, Michigan Area',
#   'score': 0.5284237623214721},
#  {'id': 75,
#   'job_title': 'Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621',
#   'location': 'San Jose, California',
#   'score': 0.4780325919389725},
#  {'id': 70,
#   'job_title': 'Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.',
#   'location': 'Virginia Beach, Virginia',
#   'score': 0.43887579739093785},
#  {'id': 96,
#   'job_title': 'Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint',
#   'location': 'Lafayette, Indiana',
#   'score': 0.4032174915075302},
#  {'id': 92,
#   'job_title': 'Seeking employment opportunities within Customer Service or Patient Care',
#   'location': 'Torrance, California',
#   'score': 0.3858268290758133},
#  {'id': 86,
#   'job_title': 'Information Systems Specialist and Programmer with a love for data and organization.',
#   'location': 'Gaithersburg, Maryland',
#   'score': 0.37796850204467775},
#  {'id': 80,
#   'job_title': 'Junior MES Engineer| Information Systems',
#   'location': 'Myrtle Beach, South Carolina Area',
#   'score': 0.3709885358810425},
#  {'id': 90,
#   'job_title': 'Undergraduate Research Assistant at Styczynski Lab',
#   'location': 'Greater Atlanta Area',
#   'score': 0.3636294424533844},
#  {'id': 77,
#   'job_title': 'Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation',
#   'location': 'Dallas/Fort Worth Area',
#   'score': 0.3539611756801605},
#  {'id': 12,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.34490605294704435},
#  {'id': 42,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.34490605294704435},
#  {'id': 55,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.34490605294704435},
#  {'id': 64,
#   'job_title': 'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR',
#   'location': 'Houston, Texas Area',
#   'score': 0.34490605294704435},
#  {'id': 93,
#   'job_title': 'Admissions Representative at Community medical center long beach',
#   'location': 'Long Beach, California',
#   'score': 0.31163416504859925},
#  {'id': 4,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 18,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 22,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 34,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 47,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 59,
#   'job_title': 'People Development Coordinator at Ryan',
#   'location': 'Denton, Texas',
#   'score': 0.30399885177612307},
#  {'id': 104,
#   'job_title': 'Director Of Administration at Excellence Logging',
#   'location': 'Katy, Texas',
#   'score': 0.29878951907157897},
#  {'id': 87,
#   'job_title': 'Bachelor of Science in Biology from Victoria University of Wellington',
#   'location': 'Baltimore, Maryland',
#   'score': 0.2914941370487213},
#  {'id': 102,
#   'job_title': 'Business Intelligence and Analytics at Travelers',
#   'location': 'Greater New York City Area',
#   'score': 0.2893262088298798},
#  {'id': 11,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.2818494647741318},
#  {'id': 41,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.2818494647741318},
#  {'id': 54,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.2818494647741318},
#  {'id': 63,
#   'job_title': 'Student at Chapman University',
#   'location': 'Lake Forest, California',
#   'score': 0.2818494647741318},
#  {'id': 95,
#   'job_title': 'Student at Westfield State University',
#   'location': 'Bridgewater, Massachusetts',
#   'score': 0.2791017383337021},
#  {'id': 91,
#   'job_title': 'Lead Official at Western Illinois University',
#   'location': 'Greater Chicago Area',
#   'score': 0.2777961194515228},
#  {'id': 98,
#   'job_title': 'Student',
#   'location': 'Houston, Texas Area',
#   'score': 0.2677120238542557},
#  {'id': 2,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.26760517358779906},
#  {'id': 16,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.26760517358779906},
#  {'id': 20,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.26760517358779906},
#  {'id': 32,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.26760517358779906},
#  {'id': 45,
#   'job_title': 'Native English Teacher at EPIK (English Program in Korea)',
#   'location': 'Kanada',
#   'score': 0.26760517358779906},
#  {'id': 8,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.2312970757484436},
#  {'id': 26,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.2312970757484436},
#  {'id': 38,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.2312970757484436},
#  {'id': 51,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.2312970757484436},
#  {'id': 61,
#   'job_title': 'HR Senior Specialist',
#   'location': 'San Francisco Bay Area',
#   'score': 0.2312970757484436},
#  {'id': 83,
#   'job_title': 'HR Manager at Endemol Shine North America',
#   'location': 'Los Angeles, California',
#   'score': 0.21969285160303118},
#  {'id': 5,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.21181770712137224},
#  {'id': 23,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.21181770712137224},
#  {'id': 35,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.21181770712137224},
#  {'id': 48,
#   'job_title': 'Advisory Board Member at Celal Bayar University',
#   'location': 'İzmir, Türkiye',
#   'score': 0.21181770712137224},
#  {'id': 103,
#   'job_title': 'Always set them up for Success',
#   'location': 'Greater Los Angeles Area',
#   'score': 0.18406260907649996},
#  {'id': 85,
#   'job_title': 'RRP Brand Portfolio Executive at JTI (Japan Tobacco International)',
#   'location': 'Greater Philadelphia Area',
#   'score': 0.17349341213703157}]
